# %%
from pybaseball import batting_stats

#set year
year = 2016

# %%
#call pybaseball to get fangraph batting data
b_1 = batting_stats(year)
b_1.columns.values
# Out:
# array(['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B',
#        '3B', 'HR', 'R', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SF', 'SH',
#        'GDP', 'SB', 'CS', 'AVG', 'GB', 'FB', 'LD', 'IFFB', 'Pitches',
#        'Balls', 'Strikes', 'IFH', 'BU', 'BUH', 'BB%', 'K%', 'BB/K', 'OBP',
#        'SLG', 'OPS', 'ISO', 'BABIP', 'GB/FB', 'LD%', 'GB%', 'FB%',
#        'IFFB%', 'HR/FB', 'IFH%', 'BUH%', 'wOBA', 'wRAA', 'wRC', 'Bat',
#        'Fld', 'Rep', 'Pos', 'RAR', 'WAR', 'Dol', 'Spd', 'wRC+', 'WPA',
#        '-WPA', '+WPA', 'RE24', 'REW', 'pLI', 'phLI', 'PH', 'WPA/LI',
#        'Clutch', 'FB% (Pitch)', 'FBv', 'SL%', 'SLv', 'CT%', 'CTv', 'CB%',
#        'CBv', 'CH%', 'CHv', 'SF%', 'SFv', 'KN%', 'KNv', 'XX%', 'PO%',
#        'wFB', 'wSL', 'wCT', 'wCB', 'wCH', 'wSF', 'wKN', 'wFB/C', 'wSL/C',
#        'wCT/C', 'wCB/C', 'wCH/C', 'wSF/C', 'wKN/C', 'O-Swing%',
#        'Z-Swing%', 'Swing%', 'O-Contact%', 'Z-Contact%', 'Contact%',
# ...

# %%
#calculate fantasy points(f_points)
b_1['f_points'] =       \
    ((b_1['1B']  * 1) + \
     (b_1['2B']  * 2) + \
     (b_1['3B']  * 3) + \
     (b_1['HR']  * 4) + \
     (b_1['R']   * 1) + \
     (b_1['RBI'] * 1) + \
     (b_1['BB']  * 1) + \
     (b_1['IBB'] * 1) + \
     (b_1['HBP'] * 1) + \
     (b_1['SB']  * 2))

#clean up dataframe
b_2 = b_1[['Season', 'Name', 'Team', 'Age', 'f_points', 'G', 'AB', 'PA', 'H', '1B', '2B',
       '3B', 'HR', 'R', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SF', 'SH',
       'SB', 'CS', 'AVG', 'GB', 'FB', 'LD', 'IFFB', 'Pitches',
       'Balls', 'Strikes', 'IFH', 'BU', 'BUH', 'BB%', 'K%', 'BB/K', 'OBP',
       'SLG', 'OPS', 'ISO', 'BABIP', 'GB/FB', 'LD%', 'GB%', 'FB%',
       'IFFB%', 'HR/FB', 'IFH%', 'BUH%','Pos','Dol', 'Spd', 'wRC+', 'WPA',
       '-WPA', '+WPA', 'RE24', 'REW', 'pLI', 'phLI', 'PH', 'WPA/LI',
       'Clutch', 'FB% (Pitch)', 'FBv', 'SL%', 'SLv', 'CT%', 'CTv', 'CB%',
       'CBv', 'CH%', 'CHv', 'SF%', 'SFv', 'KN%', 'KNv', 'XX%', 'PO%',
       'wFB', 'wSL', 'wCT', 'wCB', 'wCH', 'wSF', 'wKN', 'wFB/C', 'wSL/C',
       'wCT/C', 'wCB/C', 'wCH/C', 'wSF/C', 'wKN/C', 'O-Swing%',
       'Z-Swing%', 'Swing%', 'O-Contact%', 'Z-Contact%', 'Contact%',
       'Zone%', 'F-Strike%', 'SwStr%', 'BsR', 'Soft%', 'Med%', 'Hard%']]

#sort by fantasy points
b_2 = b_2.sort_values(by = ['f_points'], ascending=False)

#Check output
b_2.head()
# Out:
#     Season              Name          Team   Age  f_points      G     AB  \
# 34  2016.0        Mike Trout        Angels  24.0     724.0  159.0  549.0
# 56  2016.0      Mookie Betts       Red Sox  23.0     698.0  158.0  672.0
# 50  2016.0     Nolan Arenado       Rockies  25.0     685.0  160.0  618.0
# 49  2016.0       Jose Altuve        Astros  26.0     682.0  161.0  640.0
# 54  2016.0  Paul Goldschmidt  Diamondbacks  28.0     680.0  158.0  579.0
#
#        PA      H     1B  ...  O-Contact%  Z-Contact%  Contact%  Zone%  \
# 34  681.0  173.0  107.0  ...       0.706       0.870     0.814  0.423
# 56  730.0  214.0  136.0  ...       0.716       0.948     0.873  0.476
# 50  696.0  182.0  100.0  ...       0.708       0.901     0.823  0.426
# 49  717.0  216.0  145.0  ...       0.777       0.913     0.861  0.426
# 54  705.0  172.0  112.0  ...       0.696       0.844     0.794  0.426
#
#     F-Strike%  SwStr%   BsR  Soft%   Med%  Hard%
# 34      0.558   0.071   9.6  0.120  0.463  0.417
# ...

# %%
#write file out to google drive
b_2.to_csv('C:\\Users\\laine\\Google Drive\\Google Drive\\Baseball_stats\\fb_hitting_stats_' + str(year) + '.csv', encoding='utf-8', index=False)
